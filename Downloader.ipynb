# %%
# !kaggle competitions download -c siim-isic-melanoma-classification
# Out:
# ...
# ... resuming from 22704816128 bytes (90844145083 bytes left) ...
# 100%|███████████████████████████████████████▉| 106G/106G [58:41<00:00, 14.8MB/s]
# 100%|████████████████████████████████████████| 106G/106G [58:41<00:00, 25.8MB/s]

# %%
# !unzip siim-isic-melanoma-classification.zip -d siim-isic-melanoma-classification
# Out:
# Archive:  siim-isic-melanoma-classification.zip
#   inflating: siim-isic-melanoma-classification/jpeg/test/ISIC_0052060.jpg
#   inflating: siim-isic-melanoma-classification/jpeg/test/ISIC_0052349.jpg
#   inflating: siim-isic-melanoma-classification/jpeg/test/ISIC_0058510.jpg
#   inflating: siim-isic-melanoma-classification/jpeg/test/ISIC_0073313.jpg
#   inflating: siim-isic-melanoma-classification/jpeg/test/ISIC_0073502.jpg
#   inflating: siim-isic-melanoma-classification/jpeg/test/ISIC_0074618.jpg
#   inflating: siim-isic-melanoma-classification/jpeg/test/ISIC_0076801.jpg
#   inflating: siim-isic-melanoma-classification/jpeg/test/ISIC_0077586.jpg
#   inflating: siim-isic-melanoma-classification/jpeg/test/ISIC_0082004.jpg
#   inflating: siim-isic-melanoma-classification/jpeg/test/ISIC_0082785.jpg
#   inflating: siim-isic-melanoma-classification/jpeg/test/ISIC_0085332.jpg
#   inflating: siim-isic-melanoma-classification/jpeg/test/ISIC_0087243.jpg
# ...
